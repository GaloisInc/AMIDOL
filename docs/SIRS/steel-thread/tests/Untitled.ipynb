# %%
import pysces

model = pysces.model('SIR', dir='/Users/ewd/Galois/AMIDOL/docs/SIRS/steel-thread/tests')

model.mode_integrator = 'LSODA'
model.sim_start = 0.0
model.sim_end = 20
model.sim_points = 50
model.Simulate()
# Out:
# Assuming extension is .psc
# Using model directory: /Users/ewd/Galois/AMIDOL/docs/SIRS/steel-thread/tests
# /Users/ewd/Galois/AMIDOL/docs/SIRS/steel-thread/tests/SIR.psc loading .....
# Parsing file: /Users/ewd/Galois/AMIDOL/docs/SIRS/steel-thread/tests/SIR.psc
# Info: No reagents have been fixed
#
# Calculating L matrix . . . . . . .  done.
# Calculating K matrix . . . . . . . no flux conservation
#  done.
#
# LSODA time for 50 points: 0.0042359828949

# %%
model.data_sim.getSpecies(lbls=True)
# Out:
# (array([[0.00000000e+00, 9.99000000e+02, 1.00000000e+00, 0.00000000e+00],
#         [4.08163265e-01, 9.98778585e+02, 1.17708288e+00, 4.43322717e-02],
#         [8.16326531e-01, 9.98518030e+02, 1.38545612e+00, 9.65137467e-02],
#         [1.22448980e+00, 9.98211447e+02, 1.63062253e+00, 1.57930894e-01],
#         [1.63265306e+00, 9.97850744e+02, 1.91904247e+00, 2.30213776e-01],
#         [2.04081633e+00, 9.97426425e+02, 2.25829684e+00, 3.15278462e-01],
#         [2.44897959e+00, 9.96927348e+02, 2.65727600e+00, 4.15376497e-01],
#         [2.85714286e+00, 9.96340449e+02, 3.12639795e+00, 5.33152551e-01],
#         [3.26530612e+00, 9.95650427e+02, 3.67786142e+00, 6.71712014e-01],
#         [3.67346939e+00, 9.94839364e+02, 4.32593613e+00, 8.34699484e-01],
#         [4.08163265e+00, 9.93886316e+02, 5.08729390e+00, 1.02638969e+00],
#         [4.48979592e+00, 9.92766820e+02, 5.98138702e+00, 1.25179327e+00],
#         [4.89795918e+00, 9.91452347e+02, 7.03087444e+00, 1.51677874e+00],
# ...
