# %%
import plyplus, plyplus.grammars
import pprint
import pydot
from IPython.display import Image

g = plyplus.Grammar(open('ODE.g'))
results = g.parse('dS / dt = -(beta*(S*I/(S + I + R))) + gamma*I')
results.to_png_with_pydot('ode_parser_tree.png')
Image('ode_parser_tree.png')
