# %%
import numpy as np
import simpy

class AMIDOLStateVariables():
    def __init__(self):
        pass

class AMIDOLEvent():
    def __init__(self):
        pass
    
    def getRate(self):
        return(1.0)
    
    def getDelay(self):
        delay = np.random.exponential(self.getRate())
        return(delay)
    
    def isEnabled(self, statevariables):
        return(True)
    
    def fireEvent(self, statevariables):
        return(statevariables)
# Out:
# Scheduling Infect for 0.723956169516
# Scheduling Cure for 4.60255993393
# Infect	51999998.0	2.0	0.0
# Scheduling Infect for 2.35327480513
# Reactivating cure
# Scheduling Cure for 3.02804425656
# Infect	51999997.0	3.0	0.0
# Scheduling Infect for 2.60347637131
# Reactivating cure
# Scheduling Cure for 3.06559685834
# Infect	51999996.0	4.0	0.0
# Scheduling Infect for 3.50498143028
# Reactivating cure
# Scheduling Cure for 3.60696293093
# Infect	51999995.0	5.0	0.0
# Scheduling Infect for 4.09768165646
# Reactivating cure
# Scheduling Cure for 3.956760715
# Cure	51999995.0	4.0	1.0
# Scheduling Cure for 3.98298589079
# Reactivating infect
# Scheduling Infect for 5.2287477423
# Cure	51999995.0	3.0	2.0
# Scheduling Cure for 4.25126244251
# Reactivating infect
# Scheduling Infect for 4.53765495087
# Cure	51999995.0	2.0	3.0
# Scheduling Cure for 4.32182276397
# Reactivating infect
# Scheduling Infect for 5.89788176513
# Cure	51999995.0	1.0	4.0
# Scheduling Cure for 13.4674675717
# ...
