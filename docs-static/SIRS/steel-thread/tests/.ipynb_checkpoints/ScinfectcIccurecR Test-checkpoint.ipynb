# %%
import pysces

model = pysces.model('ScinfectcIccurecR.psc', dir='/Users/ewd/Galois/AMIDOL/docs/SIRS/steel-thread/BackendSteps')

model.mode_integrator = 'LSODA'
model.sim_start = 0.0
model.sim_end = 20
model.sim_points = 50
model.Simulate()
# Out:
# Using model directory: /Users/ewd/Galois/AMIDOL/docs/SIRS/steel-thread/BackendSteps
# /Users/ewd/Galois/AMIDOL/docs/SIRS/steel-thread/BackendSteps/ScinfectcIccurecR.psc loading .....
# Parsing file: /Users/ewd/Galois/AMIDOL/docs/SIRS/steel-thread/BackendSteps/ScinfectcIccurecR.psc
# Info: No reagents have been fixed
#
# Calculating L matrix . . . . . . .  done.
# Calculating K matrix . . . . . . . no flux conservation
#  done.
#
# LSODA time for 50 points: 0.0022029876709

# %%
model.data_sim.getSpecies(lbls=True)
# Out:
# (array([[0.00000000e+00, 5.19999990e+07, 1.00000000e+00, 0.00000000e+00],
#         [4.08163265e-01, 5.19999988e+07, 1.03319207e+00, 1.38300300e-01],
#         [8.16326531e-01, 5.19999987e+07, 1.06748573e+00, 2.81190544e-01],
#         [1.22448980e+00, 5.19999985e+07, 1.10291775e+00, 4.28823993e-01],
#         [1.63265306e+00, 5.19999983e+07, 1.13952582e+00, 5.81357665e-01],
#         [2.04081633e+00, 5.19999981e+07, 1.17734898e+00, 7.38954179e-01],
#         [2.44897959e+00, 5.19999979e+07, 1.21642754e+00, 9.01781566e-01],
#         [2.85714286e+00, 5.19999977e+07, 1.25680323e+00, 1.07001363e+00],
#         [3.26530612e+00, 5.19999975e+07, 1.29851906e+00, 1.24382965e+00],
#         [3.67346939e+00, 5.19999972e+07, 1.34161953e+00, 1.42341496e+00],
#         [4.08163265e+00, 5.19999970e+07, 1.38615059e+00, 1.60896109e+00],
#         [4.48979592e+00, 5.19999968e+07, 1.43215973e+00, 1.80066592e+00],
#         [4.89795918e+00, 5.19999965e+07, 1.47969604e+00, 1.99873392e+00],
# ...
